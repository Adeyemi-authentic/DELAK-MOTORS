# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_excel(r"C:\Users\USER\OneDrive\Documents\car deko edit clean.xlsx")
df
# Out:
#                                                   name  year  selling_price  \
# 0                                        Maruti 800 AC  2007          60000
# 1                             Maruti Wagon R LXI Minor  2007         135000
# 2                                 Hyundai Verna 1.6 SX  2012         600000
# 3                               Datsun RediGO T Option  2017         250000
# 4                                Honda Amaze VX i-DTEC  2014         450000
# 5                                 Maruti Alto LX BSIII  2007         140000
# 6                            Hyundai Xcent 1.2 Kappa S  2016         550000
# 7                             Tata Indigo Grand Petrol  2014         240000
# 8                             Hyundai Creta 1.6 VTVT S  2015         850000
# 9                             Maruti Celerio Green VXI  2017         365000
# 10                             Chevrolet Sail 1.2 Base  2015         260000
# ...

# %%
df.shape
# Out:
# (437, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 437 entries, 0 to 436
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           437 non-null    object
#  1   year           437 non-null    int64
#  2   selling_price  437 non-null    int64
#  3   km_driven      437 non-null    int64
#  4   fuel           437 non-null    object
#  5   seller_type    437 non-null    object
#  6   transmission   437 non-null    object
#  7   owner          437 non-null    object
#  8   horsepower     429 non-null    float64
#  9   origin         434 non-null    object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 34.3+ KB

# %%
df.drop_duplicates()
# Out:
#                                                   name  year  selling_price  \
# 0                                        Maruti 800 AC  2007          60000
# 1                             Maruti Wagon R LXI Minor  2007         135000
# 2                                 Hyundai Verna 1.6 SX  2012         600000
# 3                               Datsun RediGO T Option  2017         250000
# 4                                Honda Amaze VX i-DTEC  2014         450000
# 5                                 Maruti Alto LX BSIII  2007         140000
# 6                            Hyundai Xcent 1.2 Kappa S  2016         550000
# 7                             Tata Indigo Grand Petrol  2014         240000
# 8                             Hyundai Creta 1.6 VTVT S  2015         850000
# 9                             Maruti Celerio Green VXI  2017         365000
# 10                             Chevrolet Sail 1.2 Base  2015         260000
# ...

# %%
pd.set_option('display.max.rows',437)

# %%
df
# Out:
#                                                   name  year  selling_price  \
# 0                                        Maruti 800 AC  2007          60000
# 1                             Maruti Wagon R LXI Minor  2007         135000
# 2                                 Hyundai Verna 1.6 SX  2012         600000
# 3                               Datsun RediGO T Option  2017         250000
# 4                                Honda Amaze VX i-DTEC  2014         450000
# 5                                 Maruti Alto LX BSIII  2007         140000
# 6                            Hyundai Xcent 1.2 Kappa S  2016         550000
# 7                             Tata Indigo Grand Petrol  2014         240000
# 8                             Hyundai Creta 1.6 VTVT S  2015         850000
# 9                             Maruti Celerio Green VXI  2017         365000
# 10                             Chevrolet Sail 1.2 Base  2015         260000
# ...

# %%
df['origin']=df.origin.fillna(method='ffill')

# %%
df['horsepower']=df.horsepower.fillna(method='bfill')

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner  horsepower origin
# 0  Individual       Manual   First Owner       130.0    usa
# 1  Individual       Manual   First Owner       165.0    usa
# 2  Individual       Manual   First Owner       150.0    usa
# 3  Individual       Manual   First Owner       150.0    usa
# 4  Individual       Manual  Second Owner       140.0    usa

# %%
dft=df[['name','year','horsepower','origin','selling_price']]

# %%
dft
# Out:
#                                                   name  year  horsepower  \
# 0                                        Maruti 800 AC  2007       130.0
# 1                             Maruti Wagon R LXI Minor  2007       165.0
# 2                                 Hyundai Verna 1.6 SX  2012       150.0
# 3                               Datsun RediGO T Option  2017       150.0
# 4                                Honda Amaze VX i-DTEC  2014       140.0
# 5                                 Maruti Alto LX BSIII  2007       198.0
# 6                            Hyundai Xcent 1.2 Kappa S  2016       220.0
# 7                             Tata Indigo Grand Petrol  2014       215.0
# 8                             Hyundai Creta 1.6 VTVT S  2015       225.0
# 9                             Maruti Celerio Green VXI  2017       190.0
# 10                             Chevrolet Sail 1.2 Base  2015       170.0
# 11                            Tata Indigo Grand Petrol  2014       160.0
# ...

# %%
df['horsepower'].mean()
# Out:
# 104.34553775743707

# %%
df['horsepower'].max()
# Out:
# 230.0

# %%
df['horsepower'].min()
# Out:
# 46.0

# %%
df=df.rename(columns={'origin':'Made_in'},inplace=True)

# %%
dft.rename(columns={'origin':'Made_in'},inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9896\3604169940.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft.rename(columns={'origin':'Made_in'},inplace=True)

# %%
dft
# Out:
#                                                   name  year  horsepower  \
# 0                                        Maruti 800 AC  2007       130.0
# 1                             Maruti Wagon R LXI Minor  2007       165.0
# 2                                 Hyundai Verna 1.6 SX  2012       150.0
# 3                               Datsun RediGO T Option  2017       150.0
# 4                                Honda Amaze VX i-DTEC  2014       140.0
# 5                                 Maruti Alto LX BSIII  2007       198.0
# 6                            Hyundai Xcent 1.2 Kappa S  2016       220.0
# 7                             Tata Indigo Grand Petrol  2014       215.0
# 8                             Hyundai Creta 1.6 VTVT S  2015       225.0
# 9                             Maruti Celerio Green VXI  2017       190.0
# 10                             Chevrolet Sail 1.2 Base  2015       170.0
# 11                            Tata Indigo Grand Petrol  2014       160.0
# ...

# %%
max_hrsp=dft['horsepower'].max()
max_hrsp
# Out:
# 230.0

# %% [markdown]
# #### to get details of the car with highest horsepower

# %%
max_hrp=dft['horsepower'].idxmax()

# %%
max_hrp
# Out:
# 116

# %%
dft.loc[max_hrp]
# Out:
# name             Hyundai Creta 1.4 CRDi S
# year                                 2016
# horsepower                          230.0
# Made_in                               usa
# selling_price                      780000
# Name: 116, dtype: object

# %% [markdown]
# #### to get the top 10 cars with high horsepower without using groupby

# %%
sort_cars=dft.sort_values(by='horsepower',ascending=False)
sort_cars
# Out:
#                                                   name  year  horsepower  \
# 116                           Hyundai Creta 1.4 CRDi S  2016       230.0
# 95                     Fiat Avventura MULTIJET Emotion  2015       225.0
# 8                             Hyundai Creta 1.6 VTVT S  2015       225.0
# 13                                       Maruti 800 AC  2007       225.0
# 6                            Hyundai Xcent 1.2 Kappa S  2016       220.0
# 94                        Audi A6 2.0 TDI Premium Plus  2014       215.0
# 7                             Tata Indigo Grand Petrol  2014       215.0
# 25                     Toyota Corolla Altis 1.8 VL CVT  2018       215.0
# 27                         Hyundai Venue SX Opt Diesel  2019       210.0
# 67                                     Maruti Alto LXi  2009       208.0
# 26                                Maruti Ciaz VXi Plus  2015       200.0
# 5                                 Maruti Alto LX BSIII  2007       198.0
# ...

# %%
s10=sort_cars.head(10)
s10
# Out:
#                                 name  year  horsepower Made_in  selling_price
# 116         Hyundai Creta 1.4 CRDi S  2016       230.0     usa         780000
# 95   Fiat Avventura MULTIJET Emotion  2015       225.0     usa         350000
# 8           Hyundai Creta 1.6 VTVT S  2015       225.0     usa         850000
# 13                     Maruti 800 AC  2007       225.0     usa          60000
# 6          Hyundai Xcent 1.2 Kappa S  2016       220.0     usa         550000
# 94      Audi A6 2.0 TDI Premium Plus  2014       215.0     usa        1470000
# 7           Tata Indigo Grand Petrol  2014       215.0     usa         240000
# 25   Toyota Corolla Altis 1.8 VL CVT  2018       215.0     usa        1650000
# 27       Hyundai Venue SX Opt Diesel  2019       210.0     usa        1195000
# 67                   Maruti Alto LXi  2009       208.0     usa         151000

# %%
horsepower_plot=s10[['name','horsepower']]
horsepower_plot
# Out:
#                                 name  horsepower
# 116         Hyundai Creta 1.4 CRDi S       230.0
# 95   Fiat Avventura MULTIJET Emotion       225.0
# 8           Hyundai Creta 1.6 VTVT S       225.0
# 13                     Maruti 800 AC       225.0
# 6          Hyundai Xcent 1.2 Kappa S       220.0
# 94      Audi A6 2.0 TDI Premium Plus       215.0
# 7           Tata Indigo Grand Petrol       215.0
# 25   Toyota Corolla Altis 1.8 VL CVT       215.0
# 27       Hyundai Venue SX Opt Diesel       210.0
# 67                   Maruti Alto LXi       208.0

# %%
horsepower_plot.plot(kind='bar',)
# Out:
# <Axes: >

# %% [markdown]
# #### to get the brand of cars with lowest horsepowers

# %%
low_hrsp=dft.sort_values(by='horsepower',ascending=True)
low_hrsp
# Out:
#                                                   name  year  horsepower  \
# 102                            BMW X1 sDrive 20d xLine  2017        46.0
# 19                           Hyundai Xcent 1.2 Kappa S  2016        46.0
# 244             Toyota Innova 2.5 VX (Diesel) 8 Seater  2014        48.0
# 325                            Maruti Baleno Alpha 1.3  2019        48.0
# 326                 Ford Figo Aspire 1.5 TDCi Titanium  2017        48.0
# 117                             Maruti Swift Dzire VDI  2014        49.0
# 394                           Mahindra Scorpio REV 116  2006        52.0
# 144                               Hyundai EON Era Plus  2013        52.0
# 195                          Ford Figo Diesel Titanium  2011        52.0
# 246                    Hyundai Grand i10 1.2 CRDi Asta  2018        52.0
# 181                                Maruti Alto K10 VXI  2018        53.0
# 198                          Maruti Esteem Vxi - BSIII  2006        53.0
# ...

# %%
low_hrsp10=low_hrsp.head(10)
low_hrsp10
# Out:
#                                        name  year  horsepower Made_in  \
# 102                 BMW X1 sDrive 20d xLine  2017        46.0  europe
# 19                Hyundai Xcent 1.2 Kappa S  2016        46.0  europe
# 244  Toyota Innova 2.5 VX (Diesel) 8 Seater  2014        48.0  europe
# 325                 Maruti Baleno Alpha 1.3  2019        48.0  europe
# 326      Ford Figo Aspire 1.5 TDCi Titanium  2017        48.0  europe
# 117                  Maruti Swift Dzire VDI  2014        49.0  europe
# 394                Mahindra Scorpio REV 116  2006        52.0  europe
# 144                    Hyundai EON Era Plus  2013        52.0   japan
# 195               Ford Figo Diesel Titanium  2011        52.0     usa
# 246         Hyundai Grand i10 1.2 CRDi Asta  2018        52.0   japan
#
#      selling_price
# 102        2750000
# 19          550000
# 244        1050000
# 325         800000
# 326         700000
# 117         434000
# 394         220000
# 144         280000
# ...

# %% [markdown]
# #### the car with the highest horsepower was made in USA WHILE THE car with the lowest horsepower was made in Europe

# %%
dft1=dft.groupby('Made_in')

# %%
dft1

# %% [markdown]
# #### total number of cars made in usa

# %%
dft.groupby('Made_in').count()
# Out:
#          name  year  horsepower  selling_price
# Made_in
# europe     79    79          79             79
# japan      86    86          86             86
# usa       272   272         272            272

# %%
dft['Made_in'].count()
# Out:
# 437

# %%
dft['Made_in'].unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
dft['Made_in'].nunique()
# Out:
# 3

# %% [markdown]
# #### A client needs a new car with at least 120horsepower made in usa

# %%
df=pd.read_excel(r"C:\Users\USER\OneDrive\Documents\car deko edit clean.xlsx")
df
# Out:
#                                                   name  year  selling_price  \
# 0                                        Maruti 800 AC  2007          60000
# 1                             Maruti Wagon R LXI Minor  2007         135000
# 2                                 Hyundai Verna 1.6 SX  2012         600000
# 3                               Datsun RediGO T Option  2017         250000
# 4                                Honda Amaze VX i-DTEC  2014         450000
# 5                                 Maruti Alto LX BSIII  2007         140000
# 6                            Hyundai Xcent 1.2 Kappa S  2016         550000
# 7                             Tata Indigo Grand Petrol  2014         240000
# 8                             Hyundai Creta 1.6 VTVT S  2015         850000
# 9                             Maruti Celerio Green VXI  2017         365000
# 10                             Chevrolet Sail 1.2 Base  2015         260000
# ...

# %%
df.rename(columns={'origin':'Made_in'},inplace=True)

# %%
df
# Out:
#                                                   name  year  selling_price  \
# 0                                        Maruti 800 AC  2007          60000
# 1                             Maruti Wagon R LXI Minor  2007         135000
# 2                                 Hyundai Verna 1.6 SX  2012         600000
# 3                               Datsun RediGO T Option  2017         250000
# 4                                Honda Amaze VX i-DTEC  2014         450000
# 5                                 Maruti Alto LX BSIII  2007         140000
# 6                            Hyundai Xcent 1.2 Kappa S  2016         550000
# 7                             Tata Indigo Grand Petrol  2014         240000
# 8                             Hyundai Creta 1.6 VTVT S  2015         850000
# 9                             Maruti Celerio Green VXI  2017         365000
# 10                             Chevrolet Sail 1.2 Base  2015         260000
# ...

# %%
client=df[df['horsepower']>=120].sort_values(by=['owner','seller_type'],ascending=[True,True])
client
client.head(10)
# Out:
#                                         name  year  selling_price  km_driven  \
# 12           Toyota Corolla Altis 1.8 VL CVT  2018        1650000      25000
# 25           Toyota Corolla Altis 1.8 VL CVT  2018        1650000      25000
# 26                      Maruti Ciaz VXi Plus  2015         585000      24000
# 27               Hyundai Venue SX Opt Diesel  2019        1195000       5000
# 32                           Audi Q5 2.0 TDI  2011        1190000     175900
# 41  Mercedes-Benz E-Class E 200 CGI Elegance  2010         850000     119000
# 62                      Honda City i DTEC VX  2014         675000      90000
# 63                  Maruti Wagon R VXI BS IV  2013         300000      80000
# 66                           Toyota Etios GD  2014         525000      92000
# 86                      Honda Amaze S i-VTEC  2016         495000      11958
#
#       fuel seller_type transmission        owner  horsepower Made_in
# ...

# %% [markdown]
# ### Mike dream car is an Audi with at least 100 horsepower and his budget is around 120000

# %%
mike=df[df['name'].str.contains('Audi')]
mike.sort_values(by='selling_price',ascending=True).head(3)
# Out:
#                                     name  year  selling_price  km_driven  \
# 99  Audi A4 2.0 TDI 177 Bhp Premium Plus  2013        1150000      53000
# 32                       Audi Q5 2.0 TDI  2011        1190000     175900
# 44        Audi Q7 35 TDI Quattro Premium  2009        1250000      78000
#
#       fuel seller_type transmission        owner  horsepower Made_in
# 99  Diesel      Dealer    Automatic  First Owner       100.0     usa
# 32  Diesel      Dealer    Automatic  First Owner       121.0     usa
# 44  Diesel      Dealer    Automatic  Third Owner       175.0     usa

# %% [markdown]
# ####  the top 10 most epensive car

# %%
most_expensive_car=df.filter(items=['selling_price','name','horsepower','year']).max()
most_expensive_car
# Out:
# selling_price                  8150000
# name             Volvo V40 D3 R Design
# horsepower                       230.0
# year                              2020
# dtype: object

# %%
exp=df['selling_price'].idxmax()
exp
# Out:
# 89

# %%
df.loc[exp]
# Out:
# name             Mercedes-Benz S-Class S 350d Connoisseurs Edition
# year                                                          2017
# selling_price                                              8150000
# km_driven                                                     6500
# fuel                                                        Diesel
# seller_type                                                 Dealer
# transmission                                             Automatic
# owner                                                  First Owner
# horsepower                                                   150.0
# Made_in                                                        usa
# Name: 89, dtype: object

# %% [markdown]
# #### the main difference between the 2 methods used above in trying to get the most expensive car is that
# The filter method is giving us the maximum value for each item selected while the idmax is giving us the index of the id that has the maximum selling price
# therefore exp is the correct one

# %%
expensive=df.sort_values(by='selling_price',ascending=False)
expensive
# Out:
#                                                   name  year  selling_price  \
# 89   Mercedes-Benz S-Class S 350d Connoisseurs Edition  2017        8150000
# 101         Mercedes-Benz E-Class Exclusive E 200 BSIV  2018        4500000
# 204                      BMW 5 Series 520d Luxury Line  2017        2900000
# 96                                     Audi A8 4.2 TDI  2013        2800000
# 102                            BMW X1 sDrive 20d xLine  2017        2750000
# 163                    Jaguar XJ 5.0 L V8 Supercharged  2010        2550000
# 105                                 BMW 7 Series 730Ld  2012        2500000
# 318                            BMW 3 Series 320d Sport  2013        2000000
# 218   Mercedes-Benz New C-Class C 220 CDI BE Avantgare  2013        2000000
# 103                              Volvo V40 D3 R Design  2018        1975000
# 29                          Jaguar XF 2.2 Litre Luxury  2014        1964999
# ...

# %%
expensive.head(10)
# Out:
#                                                   name  year  selling_price  \
# 89   Mercedes-Benz S-Class S 350d Connoisseurs Edition  2017        8150000
# 101         Mercedes-Benz E-Class Exclusive E 200 BSIV  2018        4500000
# 204                      BMW 5 Series 520d Luxury Line  2017        2900000
# 96                                     Audi A8 4.2 TDI  2013        2800000
# 102                            BMW X1 sDrive 20d xLine  2017        2750000
# 163                    Jaguar XJ 5.0 L V8 Supercharged  2010        2550000
# 105                                 BMW 7 Series 730Ld  2012        2500000
# 318                            BMW 3 Series 320d Sport  2013        2000000
# 218   Mercedes-Benz New C-Class C 220 CDI BE Avantgare  2013        2000000
# 103                              Volvo V40 D3 R Design  2018        1975000
#
#      km_driven    fuel seller_type transmission         owner  horsepower  \
# ...

# %% [markdown]
# #### to get the least expensive cars

# %%
df.sort_values(by='selling_price',ascending=True).head(10)
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 137                 Maruti 800 Std  1998          40000      40000  Petrol
# 391  Hyundai Santro GLS I - Euro I  1999          50000     120000  Petrol
# 334                Tata Indica DLX  2003          50000     120000  Diesel
# 221                 Maruti Alto LX  2006          52000     120000  Petrol
# 340                  Tata Nano STD  2013          55000      25000  Petrol
# 13                   Maruti 800 AC  2007          60000      70000  Petrol
# 372                  Maruti 800 AC  2000          60000      40000  Petrol
# 0                    Maruti 800 AC  2007          60000      70000  Petrol
# 315            Maruti Zen LXi BSII  2002          60000      80000  Petrol
# 259                  Maruti 800 AC  2002          65000     100000  Petrol
#
#     seller_type transmission                 owner  horsepower Made_in
# 137  Individual       Manual  Fourth & Above Owner       150.0     usa
# ...

# %% [markdown]
# #### get the details of all ford,bmw,hyundai vehicles present in the dataframe

# %%
Ford=df[df['name'].str.contains('Ford')]
Ford
# Out:
#                                             name  year  selling_price  \
# 77        Ford EcoSport 1.5 Diesel Titanium BSIV  2017         925000
# 134    Ford Figo Aspire 1.2 Ti-VCT Titanium Plus  2015         530000
# 135  Ford EcoSport 1.5 Diesel Titanium Plus BSIV  2017         840000
# 194                    Ford Figo Diesel Titanium  2010         170000
# 195                    Ford Figo Diesel Titanium  2011         190000
# 209                    Ford Figo Petrol Titanium  2014         350000
# 243                    Ford Figo Petrol Titanium  2015         300000
# 252         Ford Fiesta Classic 1.4 SXI Duratorq  2006         110000
# 298            Ford Figo Aspire 1.2 Ti-VCT Trend  2017         530000
# 299                    Ford Figo Aspire Facelift  2018         624000
# 317             Ford Aspire Titanium Diesel BSIV  2017         700000
# 326           Ford Figo Aspire 1.5 TDCi Titanium  2017         700000
# ...

# %%
bmw=df[df['name'].str.contains('BMW')]
bmw
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 43    BMW 3 Series 320d Sport Line  2013        1550000      75800  Diesel
# 102        BMW X1 sDrive 20d xLine  2017        2750000      13000  Diesel
# 105             BMW 7 Series 730Ld  2012        2500000      48000  Diesel
# 204  BMW 5 Series 520d Luxury Line  2017        2900000      40000  Diesel
# 318        BMW 3 Series 320d Sport  2013        2000000     167223  Diesel
# 320    BMW X1 sDrive 20d Exclusive  2011        1375000      60000  Diesel
#
#     seller_type transmission         owner  horsepower Made_in
# 43       Dealer    Automatic  Second Owner       170.0     usa
# 102  Individual    Automatic   First Owner        46.0  europe
# 105      Dealer    Automatic   First Owner       170.0     usa
# 204  Individual    Automatic   First Owner        70.0   japan
# 318      Dealer    Automatic   First Owner        90.0   japan
# 320  Individual    Automatic   First Owner        92.0   japan

# %%
hyundai=df[df['name'].str.contains('Hyundai')]
hyundai
# Out:
#                                              name  year  selling_price  \
# 2                            Hyundai Verna 1.6 SX  2012         600000
# 6                       Hyundai Xcent 1.2 Kappa S  2016         550000
# 8                        Hyundai Creta 1.6 VTVT S  2015         850000
# 15                           Hyundai Verna 1.6 SX  2012         600000
# 19                      Hyundai Xcent 1.2 Kappa S  2016         550000
# 21                       Hyundai Creta 1.6 VTVT S  2015         850000
# 27                    Hyundai Venue SX Opt Diesel  2019        1195000
# 42                         Hyundai i10 Magna 1.1L  2014         229999
# 45                         Hyundai Elantra CRDi S  2012         625000
# 51                        Hyundai Santro Xing GLS  2009         150000
# 52               Hyundai Grand i10 1.2 Kappa Asta  2019         500000
# 56                    Hyundai i20 Sportz 1.4 CRDi  2018         750000
# ...
